# %% [markdown]
# # **BUSINESS PROBLEM UNDERSTANDING**

# %% [markdown]
# ### **CONTEXT**

# %% [markdown]
# In today’s business world, customers are the most valuable asset. They are the driving force behind any company’s success, particularly in industries as competitive as e-commerce. As the market becomes more saturated and competition heats up, businesses need to focus more on retaining their customers. Why? Because loyal customers are not just repeat buyers—they’re also the key to sustained revenue and long-term growth. Without them, it’s nearly impossible for any business to thrive.
#
# Customer loyalty is the backbone of survival in e-commerce. Loyal customers tend to stick around, make more purchases, and even spread the word, helping companies save on marketing costs. Building strong relationships with customers isn’t just nice-to-have; it’s a must-have strategy for any business aiming to stay ahead of the competition.
#
# Let’s explore the booming e-commerce market in Brazil. According to the Based on [eCommerce market in Brazil](https://ecommercedb.com/markets/br/all#:~:text=market%20in%20Brazil-,Brazil%20is%20the%2012th%20largest%20market%20for%20eCommerce%20with%20a%20predicted,with%206.1%25%2C%20DIY%20with%205.4%25%2C%20and%20Grocery%20with%20the%20remaining%204.6%25.,-OVERVIEW) report, Brazil is the 12th largest e-commerce market globally. It is projected to reach US$40.636 billion in revenue by 2024. The market is expanding rapidly, with a forecasted compound annual growth rate (CAGR) of 8.9% from 2024 to 2028, potentially reaching US$57.099 billion by 2028. In 2024, the market is expected to grow by 9.8%, contributing to a global e-commerce growth rate of 10.1%. Major categories driving this growth include Electronics (31.9% of revenue), Fashion (27.0%), Hobby & Leisure (14.1%), Furniture & Homeware (10.9%), Care Products (6.1%), DIY (5.4%), and Grocery (4.6%).
#
# Amid this growth, Olist has emerged as a game-changer for small and medium-sized businesses in Brazil. So, what exactly is Olist, and how does it work? Olist is a powerful e-commerce platform that helps smaller businesses sell their products online by connecting them to 13 of Brazil’s biggest marketplaces—like Amazon, Submarino, and Americanas.com—all through a single platform.
#
# Olist operates with a straightforward and effective business model designed to support small and medium-sized businesses. By partnering with major e-commerce marketplaces across Brazil, Olist allows these businesses to list their products on multiple platforms with just one contract. This integration means that sellers can access a broad customer base through Olist’s network of partners, simplifying their online presence.
#
# Sellers list their products through Olist Store, and Olist’s logistics partners handle the delivery directly to the customers. Once a purchase is made, the seller receives all necessary details to fulfill the order. After the product is shipped and delivered, or if the estimated delivery date passes, Olist sends a satisfaction survey to the customer via email. This survey allows customers to provide feedback on their shopping experience, helping Olist and the sellers to continuously improve their services.
#
# Olist generates revenue through several key channels. Primarily based on [Olist Profit](https://medium.com/@fercanc/how-can-olist-increase-its-profit-ef58e3f274e#:~:text=P%26L%20Rules,each%20order%20delivered.), Olist takes a 10% commission on the product price (excluding freight) for each order delivered through its platform. Additionally, Olist charges a monthly subscription fee of R$80 or US$14,63 per seller for access to its services. Beyond these, Olist may also generate income from premium services, such as enhanced product listings and advanced analytics, and potentially from additional advertising or promotional features. This multi-faceted approach to revenue generation ensures that Olist profits from both the volume of sales and the added value it offers to its sellers.
#
# Olist significantly impacts the Brazilian e-commerce landscape by enabling small businesses to compete on a larger scale. By simplifying the selling process and offering access to a broad network of marketplaces, Olist helps merchants reach more customers without the complexities of managing multiple sales channels and logistics on their own. This democratization of online selling supports the growth of Brazil’s e-commerce market and encourages entrepreneurship across the country.
#
# In this project, we’ll be utilizing the Brazilian E-Commerce Public Dataset by Olist, available on Kaggle. This dataset encompasses over 100,000 orders from 2016 to 2018, detailing various aspects such as order status, payment methods, prices, and customer reviews. It also includes geolocation data, providing insights into customer behavior and location patterns. This rich dataset will help us analyze trends and behaviors in Brazilian e-commerce, offering valuable insights for optimizing strategies and improving customer experiences.

# %% [markdown]
# ### **PROBLEM STATEMENT**

# %% [markdown]
# Olist, a well-known e-commerce platform in Brazil, is dealing with a **serious challenge when it comes to customer retention**. Data from 2016 to 2018 shows that **97% of customers only make one purchase and do not come back, leaving just 3% as repeat buyers**. This low retention rate has a significant impact on Olist's revenue and growth potential.
#
# Based on the provided dataset, the customer proportions by the number of purchases are:
#   - **One-time Buyers** (Single Purchase): **90,859 customers** (97%)
#   - **Repeat Buyers** (Multiple Purchases): **2,825 customers** (3%)
#
# According to [Olist Profit](https://medium.com/@fercanc/how-can-olist-increase-its-profit-ef58e3f274e#:~:text=P%26L%20Rules,each%20order%20delivered.), Olist earns a 10% commission on the product price (excluding freight) for each order delivered. From the dataset, we calculated that the **average revenue per customer’s order is approximately R$14.44**, derived from this 10% commission. Additionally, our calculations show that **repeat buyers make an average of about 2 purchases each**.
#
# Therefore, Olist's revenue from its commission can be calculated as follows:
# 1. **Revenue from One-time Buyers:**
#     - **Total Number of One-time Buyers** x **Commission per Order** = 90,859 x R$14.44 = R$1,312,003
#
# 2. **Revenue from Repeat Buyers:**
#     - **Total Orders by Repeat Buyers:**
#       - **Total Number of Repeat Buyers** x **Average Purchases per Repeat Buyer** = 2,825 x 2 = 5,650
#     - **Total Revenue from Repeat Buyers:**
#       - **Total Orders by Repeat Buyers** x **Commission per Order** = 5,650 x R$14.44 = R$81,586
#
# 3. **Total Revenue from All Customers:**
#     - **Total Revenue from One-time Buyers** + **Total Revenue from Repeat Buyers** = R$1,312,003 + R$81,586 = **R$1,393,589**
#
# The code-generated calculation confirms that Olist's revenue is also approximately R$1.39 million, based on summing all commissions (10% of the product prices) from all ordered products. This verifies that the previous information is accurate and aligns with the dataset. Therefore, this information can be used to estimate the potential revenue for the target goals.
#
# **Olist’s revenue of approximately R$1.39 million from 2016 to 2018 represents only a tiny fraction of the overall Brazilian e-commerce market**. According to [eCommerce Revenue Development in Brazil](https://ecommercedb.com/insights/ecommerce-revenue-development-in-brazil/1006606#:~:text=In%202017%2C%20the%20revenue%20stood%20at%20US%2419.5%20billion%2C%20marking%20the%20starting%20point%20of%20this%20upward%20trajectory.%20Subsequent%20years%20saw%20a%20steady%20increase%2C%20with%202018%20recording%20US%2420.2%20billion%20and%202019%20reaching%20US%2423.7%20billion.), the **Brazilian e-commerce market was valued at US$19.5 billion in 2017. It grew to US$20.2 billion in 2018** and reached US$23.7 billion in 2019. In this rapidly expanding market, Olist’s share is very small. The current problem is that 97% of Olist’s customers make only a single purchase and never return. This low retention rate means Olist is missing out on a massive opportunity for growth.
#
# Imagine if Olist could turn even a small percentage of those one-time buyers into repeat customers. The potential revenue increase would be substantial. Repeat customers are not only more profitable because they buy more often but also because they contribute to a more stable and predictable revenue stream. In short, improving customer retention is not just a nice-to-have; it’s crucial for Olist’s survival and growth. To thrive in the booming Brazilian e-commerce market, Olist must focus on turning one-time buyers into loyal customers. This shift could transform their financial performance and help capture a larger share of the rapidly growing market.

# %% [markdown]
# ### **GOALS**

# %% [markdown]
# The goal is to develop a recommendation system that effectively increases customer retention, specifically aiming to boost the percentage of repeat buyers from 3% to 5%. This increase will drive higher revenues by converting more one-time buyers into loyal customers, and ensure more stable growth in the competitive Brazilian e-commerce market. As stated by [Ashwani Patel](https://www.linkedin.com/pulse/in-depth-read-how-do-recommender-systems-work-ashwani-patel/#:~:text=What%20are%20the,satisfaction%20and%20retention.) and [Zuzanna Pajorska](https://stratoflow.com/product-recommender-for-ecommerce/#:~:text=What%20are%20the,through%20personalized%20suggestions.), recommendation systems are powerful tools and the most effective strategy for boosting revenue and improving customer retention. By providing personalized product suggestions, it encourages repeat purchases, leading to higher sales and a more loyal customer base.
#
# Therefore, below is the calculation of the expected revenue growth by implementing the recommendation system. Since the above information in the problem statement aligns with the dataset, we will use the information to calculate our target goals.
#
# **Previous Information**:
# 1. **Total Customers**: 93,684 customers
# 2. **Number of Repeat Buyers**: 2,825 customers
# 3. **Current Repeat Buyers Percentage**: 3%
# 4. **Average Number of Purchases per Repeat Buyers**: 2 purchases
# 5. **Average Revenue per Customer's Order**: R$14.44
# 6. **Revenue from Current Repeat Buyers**: R$81,586
# 7. **Current Total Revenue from All Customers**: R$1,393,589
#
# **Expected Revenue Growth Calculation**:
# 1. **Target Repeat Buyer Percentage: 5%**
#     - **Target Number of Repeat Buyers**:
#         - 5% of total customers = 5% × 93,684 customers = 4,684 customers
#     - **Expected Revenue from Target Repeat Buyers**:
#         - **Total Orders by Target Repeat Buyers**:
#             - 4,684 customers × 2 purchases = 9,368 orders
#         - **Total Revenue from Target Repeat Buyers**:
#             - 9,368 orders × R$14.44 = **R$135,273**
#
# 2. **Expected Revenue Growth**:
#     - **Increase in Revenue from Repeat Buyers**:
#         - R$135,273 (target) - R$81,586 (current) = **R$53,687**
#     - **Expected Total Revenue After Increase**:
#         - R$1,393,589 + R$53,687 = **R$1,447,276**
#     - **Expected Revenue Growth Percentage**:
#         - ((R$1,447,276 - R$1,393,589) / R$1,393,589) × 100 = **3.85%**
#
# By achieving the target of **increasing repeat buyers to 5%**, Olist can expect an approximate **revenue increase of R$53,687**, which represents a **3.85% growth in total revenue**. This highlights the significant impact of the recommendation system in driving business growth.

# %% [markdown]
# ### **ANALYTICAL APPROACH (MODELS AND EVALUATION METRICS)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('sample_data/df_olist.csv')
df
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 116034  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 116035  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 116036  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 116037  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 116038  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#                 customer_city customer_state  \
# 0                      franca             SP
# 1       sao bernardo do campo             SP
# 2                   sao paulo             SP
# 3             mogi das cruzes             SP
# 4                    campinas             SP
# ...                       ...            ...
# 116034              sao paulo             SP
# 116035        taboao da serra             SP
# 116036              fortaleza             CE
# 116037                 canoas             RS
# 116038                  cotia             SP
#
#                                 order_id order_status  \
# 0       00e7ee1b050b8499577073aeb2a297a1    delivered
# 1       29150127e6685892b6eab3eec79f59c7    delivered
# 2       b2059ed67ce144a36e2aa97d2c9e9ad2    delivered
# 3       951670f92359f4fe4a63112aa7306eba    delivered
# 4       6b7d50bd145f6fc7f33cebabd7e49d0f    delivered
# ...                                  ...          ...
# 116034  6760e20addcf0121e9d58f2f1ff14298    delivered
# 116035  9ec0c8947d973db4f4e8dcf1fbfa8f1b    delivered
# 116036  fed4434add09a6f332ea398efd656a5c    delivered
# 116037  e31ec91cea1ecf97797787471f98a8c2    delivered
# 116038  28db69209a75e59f20ccbb5c36a20b90    delivered
#
#        order_purchase_timestamp order_delivered_customer_date  \
# 0           2017-05-16 15:05:35           2017-05-25 10:35:35
# 1           2018-01-12 20:48:24           2018-01-29 12:41:19
# 2           2018-05-19 16:07:45           2018-06-14 17:58:51
# 3           2018-03-13 16:06:38           2018-03-28 16:04:25
# 4           2018-07-29 09:51:30           2018-08-09 20:55:48
# ...                         ...                           ...
# 116034      2018-04-07 15:48:17           2018-04-13 20:06:37
# 116035      2018-04-04 08:20:22           2018-04-11 18:54:45
# 116036      2018-04-08 20:11:50           2018-05-09 19:03:15
# 116037      2017-11-03 21:08:33           2017-11-16 19:58:39
# 116038      2017-12-19 14:27:23           2017-12-26 18:42:36
#
#        order_estimated_delivery_date  order_item_id  ... payment_installments  \
# 0                2017-06-05 00:00:00            1.0  ...                  2.0
# 1                2018-02-06 00:00:00            1.0  ...                  8.0
# 2                2018-06-13 00:00:00            1.0  ...                  7.0
# 3                2018-04-10 00:00:00            1.0  ...                  1.0
# 4                2018-08-15 00:00:00            1.0  ...                  8.0
# ...                              ...            ...  ...                  ...
# 116034           2018-04-25 00:00:00            1.0  ...                  6.0
# 116035           2018-04-20 00:00:00            1.0  ...                  3.0
# 116036           2018-05-02 00:00:00            1.0  ...                  5.0
# 116037           2017-12-05 00:00:00            1.0  ...                  2.0
# 116038           2018-01-08 00:00:00            1.0  ...                  1.0
#
#        payment_value   product_category_name  product_description_lenght  \
# 0             146.87        office_furniture                      1141.0
# 1             335.48              housewares                      1002.0
# 2             157.73        office_furniture                       955.0
# 3             173.30        office_furniture                      1066.0
# 4             252.25            home_confort                       407.0
# ...              ...                     ...                         ...
# 116034         88.78  books_general_interest                       489.0
# 116035        129.06          sports_leisure                      1193.0
# 116036         56.04           health_beauty                       575.0
# 116037        711.07           watches_gifts                       452.0
# 116038         21.77               perfumery                       933.0
#
#         product_photos_qty product_weight_g      seller_city  seller_state  \
# 0                      1.0           8683.0  itaquaquecetuba            SP
# 1                      3.0          10150.0           itajai            SC
# 2                      1.0           8267.0  itaquaquecetuba            SP
# 3                      1.0          12160.0  itaquaquecetuba            SP
# 4                      1.0           5200.0         ibitinga            SP
# ...                    ...              ...              ...           ...
# 116034                 2.0            611.0            garca            SP
# 116035                 1.0           1211.0       araraquara            SP
# 116036                 1.0            870.0        sao paulo            SP
# 116037                 1.0            710.0          guariba            SP
# 116038                 1.0             50.0        sao paulo            SP
#
#        review_score  review_answer_timestamp
# 0               4.0      2017-05-30 22:34:40
# 1               5.0      2018-02-10 22:43:29
# 2               5.0      2018-06-15 12:10:59
# 3               5.0      2018-04-02 18:36:47
# 4               5.0      2018-08-17 01:59:52
# ...             ...                      ...
# 116034          4.0      2018-04-28 11:15:04
# 116035          5.0      2018-04-16 10:36:05
# 116036          1.0      2018-05-08 01:41:07
# 116037          5.0      2017-11-19 23:34:18
# 116038          5.0      2017-12-27 23:21:06
#
# [116039 rows x 26 columns]

# %% [markdown]
# ## **BUSINESS PROBLEM AND TARGET CALCULATION**

# %%
# total number of customers
total_cust = df['customer_unique_id'].nunique()



# customer distribution based on the number of purchases and their percentage
customer_order_counts = df.groupby('customer_unique_id')['order_id'].nunique()

buyer_classification = []
for count in customer_order_counts:
    if count > 1:
        buyer_classification.append('Repeated Buyer')
    else:
        buyer_classification.append('One-Time Buyer')

buyer_classification_series = pd.Series(buyer_classification, index=customer_order_counts.index)

distribution = buyer_classification_series.value_counts()
distribution_percentage = ((distribution / distribution.sum()) * 100).round(1)

distribution_df = pd.DataFrame({
    'Buyer Type': distribution.index,
    'Count': distribution.values,
    'Percentage': distribution_percentage.values
})



# average number of purchases per repeat buyer
repeat_buyers = customer_order_counts[customer_order_counts > 1]

total_repeat_orders = repeat_buyers.sum()

num_repeat_buyers = len(repeat_buyers)

average_repeat_orders_per_buyer = total_repeat_orders / num_repeat_buyers



# Olist commission (10% of the product's price)
olist_cut_percentage = 0.10 

df['olist_commission'] = df['price'] * olist_cut_percentage

commission_df = df[['customer_unique_id', 'order_id', 'price', 'olist_commission']]



# average revenue per customer's order (commission from 10% of the product's price)
order_revenue = df.groupby('order_id')['olist_commission'].sum()

average_revenue_per_order = order_revenue.mean()



# total revenue from all customers
total_revenue = df['olist_commission'].sum()



print(f"Total Customers: {total_cust} customers")
display(distribution_df)
print(f"Average Number of Purchases per Repeat Buyer: {average_repeat_orders_per_buyer:.0f} purchases")
display(commission_df.head(6))
print(f"Average Revenue per Customer's Order: R${average_revenue_per_order:.2f}")
print(f"\nTotal Revenue from All Customers: R${total_revenue:.2f}")
# Out:
# Total Customers: 93684 customers
#        Buyer Type  Count  Percentage
# 0  One-Time Buyer  90859        97.0
# 1  Repeated Buyer   2825         3.0
# Average Number of Purchases per Repeat Buyer: 2 purchases
#                  customer_unique_id                          order_id   price  \
# 0  861eff4711a542e4b93843c6dd7febb0  00e7ee1b050b8499577073aeb2a297a1  124.99
# 1  290c77bc529b7ac935b93aa66c333dc3  29150127e6685892b6eab3eec79f59c7  289.00
# 2  060e732b5b29e8181a18229c7b0b2b5e  b2059ed67ce144a36e2aa97d2c9e9ad2  139.94
# 3  259dac757896d24d7702b9acbbff3f3c  951670f92359f4fe4a63112aa7306eba  149.94
# 4  345ecd01c38d18a9036ed96c73b8d066  6b7d50bd145f6fc7f33cebabd7e49d0f  230.00
# 5  4c93744516667ad3b8f1fb645a3116a4  5741ea1f91b5fbab2bd2dc653a5b5099  259.90
#
#    olist_commission
# 0            12.499
# 1            28.900
# 2            13.994
# 3            14.994
# 4            23.000
# 5            25.990
# Average Revenue per Customer's Order: R$14.44
#
# Total Revenue from All Customers: R$1397922.74

# %% [markdown]
# ## **NUMERICAL FEATURES ANALYSIS**

# %% [markdown]
# ### **Data Distribution and Outliers**

# %%
from scipy.stats import normaltest, skew

numerical_features = [col for col in df.describe().columns if col != 'review_score']
numerical_features
# Out:
# ['order_item_id',
#  'price',
#  'freight_value',
#  'payment_sequential',
#  'payment_installments',
#  'payment_value',
#  'product_description_lenght',
#  'product_photos_qty',
#  'product_weight_g',
#  'olist_commission']

# %%
def outlier_stats(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = column[(column < lower_bound) | (column > upper_bound)]
    count_outliers = len(outliers)
    percentage_outliers = (count_outliers / len(column)) * 100
    return count_outliers, percentage_outliers

# %%
for col in numerical_features:
    count_outliers, pct_outliers = outlier_stats(df[col])
    fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(7.5, 5), 
                                    gridspec_kw={"height_ratios": (.15, .85),
                                                "hspace": 0.05})

    # Test for normal distribution and calculate skewness
    stat, pvalue = normaltest(df[col].dropna())
    skewness = skew(df[col].dropna())

    if pvalue > 0.05:
        distribution_info = f'\np = {pvalue:.3f} (Normal Distribution)\nSkewness = {skewness:.2f}\n{count_outliers} Outliers ({pct_outliers:.2f}%)'
        hist_color = '#85C1E9'
        box_color = '#7DCEA0'
    else:
        if skewness > 0:
            skew_type = 'Right Skewed'
        elif skewness < 0:
            skew_type = 'Left Skewed'
        else:
            skew_type = 'Symmetric'

        distribution_info = f'\np = {pvalue:.3f} (NOT Normal Distribution)\nSkewness = {skewness:.2f} ({skew_type})\n{count_outliers} Outliers ({pct_outliers:.2f}%)'
        hist_color = '#85C1E9'
        box_color = '#7DCEA0'

    ax1.set_title(f"Distribution of {col}\n{distribution_info}", fontsize=10, color="black")
    sns.boxplot(x=df[col], ax=ax1, color=box_color, linecolor='black', flierprops=dict(marker='d', markersize=6, markeredgecolor='None', markerfacecolor='black'))
    ax1.set(xlabel="")

    sns.histplot(data=df[col], ax=ax2, stat="probability", kde=True, bins=50, color=hist_color)

    plt.show()

# %% [markdown]
# ## **THE EFFECT OF VOUCHER ON REPEAT BUYERS**

# %%
repeat_buyer_ids = customer_order_counts[customer_order_counts > 1].index
repeat_buyer_data = df[df['customer_unique_id'].isin(repeat_buyer_ids)]

print(f'Total Repeat Buyers: {repeat_buyer_ids.nunique()} customers')
print(f'Total Orders from All Repeat Buyers: {repeat_buyer_data['order_id'].nunique()} orders')
# Out:
# Total Repeat Buyers: 2825 customers
# Total Orders from All Repeat Buyers: 5965 orders

# %%
order_with_voucher_payments = repeat_buyer_data[repeat_buyer_data['payment_type'] == 'voucher']

num_orders_with_voucher = order_with_voucher_payments['order_id'].nunique()
total_orders = repeat_buyer_data['order_id'].nunique()

percentage_orders_with_voucher = (num_orders_with_voucher / total_orders) * 100

average_vouchers_per_order = order_with_voucher_payments.groupby('order_id')['payment_sequential'].sum().mean()

print(f"Number of orders using vouchers: {num_orders_with_voucher}")
print(f"Percentage of orders using vouchers: {percentage_orders_with_voucher:.2f}%")
print(f"Average number of vouchers used per order: {average_vouchers_per_order:.0f}")
# Out:
# Number of orders using vouchers: 318
# Percentage of orders using vouchers: 5.33%
# Average number of vouchers used per order: 7
